# %%
# https://github.com/dsdanielpark/Bard-API
# %pip install bardapi
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting bardapi
#   Downloading bardapi-0.1.11-py3-none-any.whl (8.8 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from bardapi) (2.27.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->bardapi) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->bardapi) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->bardapi) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->bardapi) (3.4)
# Installing collected packages: bardapi
# Successfully installed bardapi-0.1.11

# %%
from bardapi import Bard

bard = Bard(token=token)
bard.get_answer("나와 내 동년배들이 좋아하는 뉴진스에 대해서 알려줘")['content']
# Out:
# '90년대생들이 좋아하는 뉴진스는 2022년 7월 13일에 데뷔한 6인조 걸그룹입니다. 멤버는 은비, 채린, 수민, 지우, 민지, 혜린으로 구성되어 있습니다. 뉴진스는 데뷔곡 "Attention"으로 데뷔와 동시에 큰 인기를 얻었습니다. "Attention"은 90년대 뉴잭스윙과 하우스 비트를 기반으로 한 곡으로, 중독성 강한 멜로디와 가사로 많은 사랑을 받았습니다. 뉴진스는 "Attention"으로 멜론, 지니, 벅스 등 주요 음원 차트에서 1위를 차지했으며, 음악방송에서도 1위를 차지했습니다. 뉴진스는 데뷔곡 "Attention" 외에도 "Hype Boy", "Cookie", "Hurt" 등의 곡으로 큰 사랑을 받았습니다. 뉴진스는 90년대 음악을 현대적으로 재해석한 음악으로 많은 사랑을 받고 있습니다. 뉴진스는 앞으로도 90년대 음악을 사랑하는 많은 사람들에게 사랑받는 그룹이 될 것으로 기대됩니다.\r\n\r\n90년대생들이 뉴진스를 좋아하는 이유는 다음과 같습니다.\r\n\r\n* 뉴진스는 90년대 음악을 현대적으로 재해석한 음악을 하고 있습니다.\r\n* 뉴진스의 멤버들은 모두 90년대생으로, 90년대 음악에 대한 애정이 많습니다.\r\n* 뉴진스는 90년대생들의 추억을 자극하는 음악을 하고 있습니다.\r\n* 뉴진스는 90년대생들의 마음을 사로잡는 외모와 실력을 가지고 있습니다.\r\n\r\n90년대생들은 뉴진스의 음악을 들으면서 90년대로 돌아간 듯한 기분을 느낄 수 있습니다. 뉴진스의 음악은 90년대생들에게 추억과 위로를 주고 있습니다.'

# %%
from bardapi import Bard
import os

Bard().get_answer("나와 내 동년배들이 좋아하는 뉴진스에 대해서 알려줘")['content']
# Out:
# '한국의 10대들은 최근 몇 년 동안 다양한 뉴진스를 즐기고 있습니다. 가장 인기 있는 뉴진스 중 일부는 다음과 같습니다.\n\n* 케이팝: 케이팝은 한국의 대중 음악 장르로, 전 세계적으로 인기를 얻고 있습니다. 케이팝은 댄스, 팝, 록, 힙합 등 다양한 장르를 포함하며, 화려한 퍼포먼스와 매력적인 멜로디로 많은 사람들의 사랑을 받고 있습니다.\n* 한국 드라마: 한국 드라마는 최근 몇 년 동안 전 세계적으로 인기를 얻고 있습니다. 한국 드라마는 흥미진진한 스토리와 매력적인 캐릭터로 많은 사람들의 사랑을 받고 있습니다.\n* 한국 영화: 한국 영화는 최근 몇 년 동안 전 세계적으로 인기를 얻고 있습니다. 한국 영화는 독창적인 스토리와 뛰어난 연출로 많은 사람들의 사랑을 받고 있습니다.\n* 한국 음식: 한국 음식은 최근 몇 년 동안 전 세계적으로 인기를 얻고 있습니다. 한국 음식은 맛있고 건강하며, 다양한 종류의 음식이 있습니다.\n\n한국의 10대들은 이러한 뉴진스를 통해 한국의 문화와 역사를 배우고, 한국의 매력에 빠져들고 있습니다.'

# %%
import bardapi
import os

# set your __Secure-1PSID value to key

# set your input text
input_text = "나와 내 동년배들이 좋아하는 뉴진스에 대해서 알려줘"

# Send an API request and get a response.
response = bardapi.core.Bard(token).get_answer(input_text)

# Print response
print(response)
# Out:
# {'content': '네, 뉴진스에 대해 알려드리겠습니다. 뉴진스는 2022년 7월 22일에 데뷔한 7인조 걸그룹입니다. 뉴진스는 하이브 산하의 레이블인 쏘스뮤직에서 데뷔한 그룹으로, BTS의 여동생 그룹으로도 알려져 있습니다. 뉴진스의 멤버는 해린, 수연, 지우, 유진, 민지, 은진, 예린으로 이루어져 있습니다. 뉴진스는 데뷔곡 "OMG"로 큰 인기를 얻으며, 싱가포르 음원차트 1위를 차지했습니다. 뉴진스의 노래는 대부분 팝 장르로, 청춘과 사랑을 주제로 한 밝고 경쾌한 분위기의 곡들이 많습니다. 뉴진스의 멤버들은 모두 10대인 만큼, 패션과 스타일링에도 많은 관심을 받고 있습니다. 뉴진스는 귀여운 액세서리를 좋아하는 싱가포르인들과 특히 학생들에게 큰 인기를 끌고 있습니다. 현재 각종 싱가포르 온라인 쇼핑몰에서는 뉴진스와 관련된 굿즈들과 앨범들이 판매되고 있으며, 싱가포르 대표 중고거래 사이트(Carousell)에서도 뉴진스 관련 굿즈들을 사고파는 것을 실시간으로 확인할 수 있습니다. 현지 소비자들의 이 같은 모습은 BTS 이후 처음으로 느껴지는 뉴진스의 폭풍 같은 인기를 방증합니다.\n\n뉴진스는 10대들에게 인기 있는 이유는 다음과 같습니다.\n\n* 뉴진스의 노래는 청춘과 사랑을 주제로 한 밝고 경쾌한 분위기의 곡들이 많습니다.\n* 뉴진스의 멤버들은 모두 10대인 만큼, 패션과 스타일링에도 많은 관심을 받고 있습니다.\n* 뉴진스는 싱가포르 내 케이팝 주요 소비층인 10대와 20대 청춘 모두에게 큰 공감을 이끌어내고 있습니다.\n\n뉴진스는 앞으로도 10대들에게 많은 사랑을 받을 것으로 기대됩니다.', 'conversation_id': 'c_7aa29e09ac239ce7', 'response_id': 'r_7aa29e09ac2395a5', 'factualityQueries': [], 'textQuery': ['10대에게 인기 있는 뉴진스', 1], 'choices': [{'id': 'rc_7aa29e09ac239946', 'content': ['네, 뉴진스에 대해 알려드리겠습니다. 뉴진스는 2022년 7월 22일에 데뷔한 7인조 걸그룹입니다. 뉴진스는 하이브 산하의 레이블인 쏘스뮤직에서 데뷔한 그룹으로, BTS의 여동생 그룹으로도 알려져 있습니다. 뉴진스의 멤버는 해린, 수연, 지우, 유진, 민지, 은진, 예린으로 이루어져 있습니다. 뉴진스는 데뷔곡 "OMG"로 큰 인기를 얻으며, 싱가포르 음원차트 1위를 차지했습니다. 뉴진스의 노래는 대부분 팝 장르로, 청춘과 사랑을 주제로 한 밝고 경쾌한 분위기의 곡들이 많습니다. 뉴진스의 멤버들은 모두 10대인 만큼, 패션과 스타일링에도 많은 관심을 받고 있습니다. 뉴진스는 귀여운 액세서리를 좋아하는 싱가포르인들과 특히 학생들에게 큰 인기를 끌고 있습니다. 현재 각종 싱가포르 온라인 쇼핑몰에서는 뉴진스와 관련된 굿즈들과 앨범들이 판매되고 있으며, 싱가포르 대표 중고거래 사이트(Carousell)에서도 뉴진스 관련 굿즈들을 사고파는 것을 실시간으로 확인할 수 있습니다. 현지 소비자들의 이 같은 모습은 BTS 이후 처음으로 느껴지는 뉴진스의 폭풍 같은 인기를 방증합니다.\n\n뉴진스는 10대들에게 인기 있는 이유는 다음과 같습니다.\n\n* 뉴진스의 노래는 청춘과 사랑을 주제로 한 밝고 경쾌한 분위기의 곡들이 많습니다.\n* 뉴진스의 멤버들은 모두 10대인 만큼, 패션과 스타일링에도 많은 관심을 받고 있습니다.\n* 뉴진스는 싱가포르 내 케이팝 주요 소비층인 10대와 20대 청춘 모두에게 큰 공감을 이끌어내고 있습니다.\n\n뉴진스는 앞으로도 10대들에게 많은 사랑을 받을 것으로 기대됩니다.']}, {'id': 'rc_7aa29e09ac2392bb', 'content': ['뉴진스는 2022년 7월 22일에 데뷔한 7인조 걸그룹입니다. 뉴진스는 하이브의 여동생 그룹으로, 데뷔 전부터 큰 관심을 받았습니다. 뉴진스의 멤버들은 모두 10대이며, 밝고 청순한 이미지로 많은 사랑을 받고 있습니다. 뉴진스의 음악은 팝, 댄스, 힙합 등 다양한 장르를 아우르고 있습니다. 뉴진스는 데뷔 앨범 "OMG"로 큰 인기를 얻었으며, 현재까지도 많은 사랑을 받고 있습니다. 뉴진스는 싱가포르뿐만 아니라 전 세계적으로 인기를 얻고 있으며, 블랙핑크의 뒤를 이을 걸그룹이라 해도 과언이 아닙니다.\n\n뉴진스는 10대에게 인기가 많습니다. 뉴진스의 멤버들은 모두 10대이며, 밝고 청순한 이미지로 많은 사랑을 받고 있습니다. 또한 뉴진스의 음악은 팝, 댄스, 힙합 등 다양한 장르를 아우르고 있어, 10대의 다양한 취향을 만족시킬 수 있습니다. 뉴진스는 10대에게 꿈과 희망을 주는 그룹으로, 10대들의 많은 사랑을 받고 있습니다.\n\n뉴진스의 인기 요인은 다음과 같습니다.\n\n* 10대 멤버들의 밝고 청순한 이미지\n* 다양한 장르의 음악\n* 꿈과 희망을 주는 메시지\n\n뉴진스는 앞으로도 10대에게 사랑받는 걸그룹으로 성장할 것으로 기대됩니다.']}, {'id': 'rc_7aa29e09ac239c30', 'content': ['뉴진스는 2022년 7월 22일에 데뷔한 9인조 걸그룹입니다. 하이브에서 만든 두 번째 걸그룹으로, BTS의 여동생 그룹으로 알려져 있습니다. 뉴진스의 멤버는 은서, 지은, 해린, 미연, 수진, 소희, 예지, 유진, 다현입니다. 뉴진스는 데뷔곡 "OMG"로 데뷔와 동시에 한국 가요계에서 큰 인기를 얻었습니다. "OMG"는 청춘과 사랑을 주제로 한 경쾌하고 발랄한 팝 장르의 곡으로, 싱가포르 내 케이팝 주요 소비층인 10대와 20대 청춘 모두에게 큰 공감을 이끌어내고 있습니다. 또한 뉴진스 10대 멤버들의 패션과 스타일링은 평소에도 귀여운 액세사리를 좋아하는 싱가포르인들과 특히 학생들에게 큰 인기를 끌고 있습니다. 현재 각종 싱가포르 온라인 쇼핑몰에서는 뉴진스와 관련된 굿즈들과 앨범들이 판매되고 있으며 싱가포르 대표 중고거래 사이트(Carousell)에서도 뉴진스 관련 굿즈들을 사고파는 것을 실시간으로 확인할 수 있습니다. 현지 소비자들의 이 같은 모습은 BTS 이후 처음으로 느껴지는 뉴진스의 폭풍 같은 인기를 방증합니다.\n\n뉴진스는 싱가포르에서 뿐만 아니라 전 세계적으로 큰 인기를 끌고 있습니다. 2023년 1월 2일에 공개된 뉴진스의 "OMG"는 2월에도 싱가포르 음원차트 순위 1위를 지키고 있습니다. 그 뒤를 이어 "Ditto"가 3위, 작년 데뷔 EP에서 공개된 4곡 중 하나인 "Hype Boy"가 여전히 8위를 지키고 있습니다. 이처럼 총 3곡의 뉴진스 음원이 10위권 내에 자리 잡고 있습니다.\n\n1위를 차지한 "OMG"는 청춘과 사랑을 주제로 한 경쾌하고 발랄한 팝 장르의 곡입니다. 해당 곡은 싱가포르 내 케이팝 주요 소비층인 10대와 20대 청춘 모두에게 큰 공감을 이끌어내고 있습니다. 또한 뉴진스 10대 멤버들의 패션과 스타일링은 평소에도 귀여운 액세사리를 좋아하는 싱가포르인들과 특히 학생들에게 큰 인기를 끌고 있습니다. 현재 각종 싱가포르 온라인 쇼핑몰에서는 뉴진스와 관련된 굿즈들과 앨범들이 판매되고 있으며 싱가포르 대표 중고거래 사이트(Carousell)에서도 뉴진스 관련 굿즈들을 사고파는 것을 실시간으로 확인할 수 있습니다. 현지 소비자들의 이 같은 모습은 BTS 이후 처음으로 느껴지는 뉴진스의 폭풍 같은 인기를 방증합니다.\n\n이외에도 싱가포르 싱어송라이터 Boon Hui Lu(문혜여)가 뉴진스의 "OMG"를 중국어로 번역해 커버한 영상은 큰 관심을 받기도 했습니다. 또한 2월 초에는 "뉴진스의 팬인 싱가포르인 남성이 멤버 해린의 얼굴을 핸드폰 배경화면으로 설정한 뒤 복권을 사 약 300만 원 정도의 복권에 당첨됐다."는 보도도 실린 바 있습니다. 이를 본 많은 사람들은 고양이를 닮은 해린이를 복을 주는 일본 고양이, 마네키네코에 빗대어 "궁극의 마네키네코"라며 농담을 건넸습니다. 이처럼 현재 싱가포르는 뉴진스에 대한 많은 관심으로 아주 뜨거운 분위기입니다.']}]}

# %%
input_text = """
내가 다음에 쓰는 영어 문장에서 단어가 틀리거나 문법적으로 틀리는 부분을 교정해줘. 그리고 실생활에서 사용되는 더 자연스러운 문장이 있으면 해당 문장을 추천해줘.
I needs to prepare the AI project that use 'Bard' AI model.
"""

response = bardapi.core.Bard(token).get_answer(input_text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5b3b401b7478> in <cell line: 6>()
#       4 """
#       5
# ----> 6 response = bardapi.core.Bard(token).get_answer(input_text)
#
# NameError: name 'bardapi' is not defined

# %%
print(response['content'])
# Out:
# Sure, I can help you with that. Here is the corrected sentence:
#
# **I need to prepare an AI project that uses the Bard AI model.**
#
# The original sentence had a few errors:
#
# * "needs" should be "need" because it is in the singular form.
# * "to prepare" should be "to prepare an" because it is followed by a noun.
# * "use" should be "uses" because it is in the third person singular form.
#
# The revised sentence is more natural and grammatically correct. It is also more specific because it specifies that the project will use the Bard AI model.
#
# Here are some other ways to say the same thing:
#
# * "I need to prepare an AI project that uses the Bard AI model."
# * "I am working on an AI project that uses the Bard AI model."
# * "I am developing an AI project that uses the Bard AI model."
#
# I hope this helps!
